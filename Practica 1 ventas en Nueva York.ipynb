# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np

# %%
en = create_engine('mysql://root:AIPL@lol14@localhost/ventasNY')
en.connect()

# %%
cdd = pd.read_csv('/home/spqr14/Documentos/Minería/mineria/Práctica 1/datos/nyc-rolling-sales.csv', encoding='utf8')

# %%
cdd.head()
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ...  \
# 0    6                                  C2            153 AVENUE B  ...
# 1   26                                  C7   234 EAST 4TH   STREET  ...
# ...

# %%
cdd['id'] = cdd.index+1
cdd.describe()
# Out:
#          Unnamed: 0       BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  84548.000000  84548.000000  84548.000000  84548.000000  84548.000000
# mean   10344.359878      2.998758   4237.218976    376.224015  10731.991614
# std     7151.779436      1.289790   3568.263407    658.136814   1290.879147
# min        4.000000      1.000000      1.000000      1.000000      0.000000
# 25%     4231.000000      2.000000   1322.750000     22.000000  10305.000000
# 50%     8942.000000      3.000000   3311.000000     50.000000  11209.000000
# 75%    15987.250000      4.000000   6281.000000   1001.000000  11357.000000
# max    26739.000000      5.000000  16322.000000   9106.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS    YEAR BUILT  \
# count       84548.000000      84548.000000  84548.000000  84548.000000
# mean            2.025264          0.193559      2.249184   1789.322976
# ...

# %%
cdd['limpiarfecha']=cdd['SALE DATE'].map(lambda x:x.replace(' ', '|').split('|'))

# %%
cdd[['fecha','hora']]=cdd.limpiarfecha.apply(pd.Series)

# %%
cdd['fecha']=pd.to_datetime(cdd.fecha)

# %%
cdd['año']=cdd['fecha'].map(lambda x:x.year)
cdd['mes']=cdd['fecha'].map(lambda x:x.month)
cdd['dia']=cdd['fecha'].map(lambda x:x.day)

# %%
cdd_tiempo = cdd[['año','mes','dia']]

# %%
cdd_tiempo.head()
# Out:
#     año  mes  dia
# 0  2017    7   19
# 1  2016   12   14
# 2  2016   12    9
# 3  2016    9   23
# 4  2016   11   17

# %%
cdd_reg = cdd[['BOROUGH','NEIGHBORHOOD']]

# %%
cdd_reg.head()
# Out:
#       BOROUGH   NEIGHBORHOOD
# 0           1  ALPHABET CITY
# 204         1        CHELSEA
# 1007        1      CHINATOWN
# 1122        1   CIVIC CENTER
# 1445        1        CLINTON

# %%
cdd_reg.drop_duplicates(inplace=True)
# Out:
# /home/spqr14/Documentos/Minería/mineria/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cdd_construccion = cdd[['GROSS SQUARE FEET','LAND SQUARE FEET']]

# %%
cdd_construccion.head()
# Out:
#   GROSS SQUARE FEET LAND SQUARE FEET
# 0              6440             1633
# 1             18690             4616
# 2              7803             2212
# 3              6794             2272
# 4              4615             2369

# %%
cdd['limpiaimpuestos']=cdd['TAX CLASS AT PRESENT'].map(lambda x:int(x[:1]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-1d3b847e8a20> in <module>
# ----> 1 cdd['limpiaimpuestos']=cdd['TAX CLASS AT PRESENT'].map(lambda x:int(x[:1]))
#
# ~/Documentos/Minería/mineria/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3380         """
#    3381         new_values = super(Series, self)._map_values(
# -> 3382             arg, na_action=na_action)
#    3383         return self._constructor(new_values,
#    3384                                  index=self.index).__finalize__(self)
#
# ~/Documentos/Minería/mineria/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1216
#    1217         # mapper is a function
# -> 1218         new_values = map_f(values, mapper)
#    1219
#    1220         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ...
